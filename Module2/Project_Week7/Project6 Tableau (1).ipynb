# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel(r'/Users/naitsaidifariza/Downloads/data_project6.xlsx', header =1 )
df
# Out:
#    at risk                  Name Career Week end date  Days since graduation  \
# 0      NaN      Valentine Parker           2022-06-23                     71
# 1        🚩     Gregoria Veum III           2022-06-23                     71
# 2      NaN     Isai Turcotte DVM           2022-06-23                     71
# 3      NaN          Alex Mueller           2022-06-23                     71
# 4      NaN            Coy Kuphal           2022-06-23                     71
# 5      NaN           Janis Bayer           2022-06-23                     71
# 6      NaN     Mr. Emelia Graham           2022-06-23                     71
# 7      NaN           Drake Hills           2022-06-23                     71
# 8      NaN         Kirk Mosciski           2022-06-23                     71
# 9      NaN         Verda Osinski           2022-06-23                     71
# 10     NaN     Lucius McCullough           2022-06-23                     71
# ...

# %%
l_c=["Name","Cohort Name","Outcome Category","Outcome Status","Track","Format","Campus"]
for col in l_c:
    df[col]=df[col].str.lower()
df
# Out:
#    at risk                  Name Career Week end date  Days since graduation  \
# 0      NaN      valentine parker           2022-06-23                     71
# 1        🚩     gregoria veum iii           2022-06-23                     71
# 2      NaN     isai turcotte dvm           2022-06-23                     71
# 3      NaN          alex mueller           2022-06-23                     71
# 4      NaN            coy kuphal           2022-06-23                     71
# 5      NaN           janis bayer           2022-06-23                     71
# 6      NaN     mr. emelia graham           2022-06-23                     71
# 7      NaN           drake hills           2022-06-23                     71
# 8      NaN         kirk mosciski           2022-06-23                     71
# 9      NaN         verda osinski           2022-06-23                     71
# 10     NaN     lucius mccullough           2022-06-23                     71
# ...

# %%
# Show the number of columns and rows 
df.shape
# Out:
# (57, 17)

# %%
# Show the types of columns 
df.dtypes
# Out:
# at risk                          object
# Name                             object
# Career Week end date     datetime64[ns]
# Days since graduation             int64
# Cohort Name                      object
# Outcome Category                 object
# Outcome Status                   object
# Track                            object
# Format                           object
# Campus                           object
# CV                                int64
# Linkedin                          int64
# Portfolio                       float64
# Soft skills score               float64
# Assessment score                 object
# Lab score                       float64
# Final project grade             float64
# dtype: object

# %%
df.describe()
# Out:
#        Days since graduation         CV   Linkedin  Portfolio  \
# count              57.000000  57.000000  57.000000  57.000000
# mean               69.052632   0.684211   0.719298   0.508947
# std                 1.746640   0.468961   0.453336   0.504188
# min                67.000000   0.000000   0.000000   0.000000
# 25%                67.000000   0.000000   0.000000   0.000000
# 50%                70.000000   1.000000   1.000000   1.000000
# 75%                71.000000   1.000000   1.000000   1.000000
# max                71.000000   1.000000   1.000000   1.000000
#
#        Soft skills score  Lab score  Final project grade
# count          38.000000  38.000000            57.000000
# mean            3.543076   4.097895             2.107193
# std             1.220954   0.620602             0.323249
# min             1.000000   2.450000             1.625000
# 25%             2.892857   3.720000             1.875000
# 50%             3.875000   4.285000             2.000000
# ...

# %%
df.isnull().sum()
# Out:
# at risk                  54
# Name                      0
# Career Week end date      0
# Days since graduation     0
# Cohort Name               0
# Outcome Category          0
# Outcome Status            0
# Track                    19
# Format                    0
# Campus                    0
# CV                        0
# Linkedin                  0
# Portfolio                 0
# Soft skills score        19
# Assessment score          0
# Lab score                19
# Final project grade       0
# dtype: int64

# %%
#remplacer les cellules vide par "-"
df['at risk']=df['at risk'].fillna(0)

# %%
df.head(4)
# Out:
#   at risk               Name Career Week end date  Days since graduation  \
# 0       0   valentine parker           2022-06-23                     71
# 1       🚩  gregoria veum iii           2022-06-23                     71
# 2       0  isai turcotte dvm           2022-06-23                     71
# 3       0       alex mueller           2022-06-23                     71
#
#   Cohort Name Outcome Category Outcome Status Track Format Campus  CV  \
# 0     cohort1        searching      searching    wd     ft    rmt   1
# 1     cohort1         excluded   not eligible    wd     ft    rmt   0
# 2     cohort1        searching      searching    wd     ft    rmt   1
# 3     cohort1        searching      searching    wd     ft    rmt   1
#
#    Linkedin  Portfolio  Soft skills score Assessment score  Lab score  \
# 0         1        1.0           3.714286            96.75       4.78
# 1         0        0.0           1.000000            48.71       3.90
# ...

# %%
df.loc[(df['at risk']!=0),"at risk"]=1

# %%
df
# Out:
#    at risk                  Name Career Week end date  Days since graduation  \
# 0        0      valentine parker           2022-06-23                     71
# 1        1     gregoria veum iii           2022-06-23                     71
# 2        0     isai turcotte dvm           2022-06-23                     71
# 3        0          alex mueller           2022-06-23                     71
# 4        0            coy kuphal           2022-06-23                     71
# 5        0           janis bayer           2022-06-23                     71
# 6        0     mr. emelia graham           2022-06-23                     71
# 7        0           drake hills           2022-06-23                     71
# 8        0         kirk mosciski           2022-06-23                     71
# 9        0         verda osinski           2022-06-23                     71
# 10       0     lucius mccullough           2022-06-23                     71
# ...

# %%
#remplacer les cellules vide par "-"
df['Track']=df['Track'].fillna("wd") 
df
# Out:
#    at risk                  Name Career Week end date  Days since graduation  \
# 0        0      valentine parker           2022-06-23                     71
# 1        1     gregoria veum iii           2022-06-23                     71
# 2        0     isai turcotte dvm           2022-06-23                     71
# 3        0          alex mueller           2022-06-23                     71
# 4        0            coy kuphal           2022-06-23                     71
# 5        0           janis bayer           2022-06-23                     71
# 6        0     mr. emelia graham           2022-06-23                     71
# 7        0           drake hills           2022-06-23                     71
# 8        0         kirk mosciski           2022-06-23                     71
# 9        0         verda osinski           2022-06-23                     71
# 10       0     lucius mccullough           2022-06-23                     71
# ...

# %%
df.loc[df["Assessment score"]==" ","Assessment score"]=0

# %%
df
# Out:
#    at risk                  Name Career Week end date  Days since graduation  \
# 0        0      valentine parker           2022-06-23                     71
# 1        1     gregoria veum iii           2022-06-23                     71
# 2        0     isai turcotte dvm           2022-06-23                     71
# 3        0          alex mueller           2022-06-23                     71
# 4        0            coy kuphal           2022-06-23                     71
# 5        0           janis bayer           2022-06-23                     71
# 6        0     mr. emelia graham           2022-06-23                     71
# 7        0           drake hills           2022-06-23                     71
# 8        0         kirk mosciski           2022-06-23                     71
# 9        0         verda osinski           2022-06-23                     71
# 10       0     lucius mccullough           2022-06-23                     71
# ...

# %%
round(df.groupby("Cohort Name")["Soft skills score"].mean())
# Out:
# Cohort Name
# cohort1    2.0
# cohort2    NaN
# cohort3    4.0
# Name: Soft skills score, dtype: float64

# %%
df.loc[(df["Cohort Name"]=="cohort2")&(df["Soft skills score"].isna()),"Soft skills score"]=2.5

# %%
df
# Out:
#    at risk                  Name Career Week end date  Days since graduation  \
# 0        0      valentine parker           2022-06-23                     71
# 1        1     gregoria veum iii           2022-06-23                     71
# 2        0     isai turcotte dvm           2022-06-23                     71
# 3        0          alex mueller           2022-06-23                     71
# 4        0            coy kuphal           2022-06-23                     71
# 5        0           janis bayer           2022-06-23                     71
# 6        0     mr. emelia graham           2022-06-23                     71
# 7        0           drake hills           2022-06-23                     71
# 8        0         kirk mosciski           2022-06-23                     71
# 9        0         verda osinski           2022-06-23                     71
# 10       0     lucius mccullough           2022-06-23                     71
# ...

# %%
round(df.groupby("Cohort Name")["Lab score"].mean())
# Out:
# Cohort Name
# cohort1    4.0
# cohort2    NaN
# cohort3    4.0
# Name: Lab score, dtype: float64

# %%
df.loc[(df["Cohort Name"]=="cohort2")&(df["Lab score"].isna()),"Lab score"]=4

# %%
df
# Out:
#    at risk                  Name Career Week end date  Days since graduation  \
# 0        0      valentine parker           2022-06-23                     71
# 1        1     gregoria veum iii           2022-06-23                     71
# 2        0     isai turcotte dvm           2022-06-23                     71
# 3        0          alex mueller           2022-06-23                     71
# 4        0            coy kuphal           2022-06-23                     71
# 5        0           janis bayer           2022-06-23                     71
# 6        0     mr. emelia graham           2022-06-23                     71
# 7        0           drake hills           2022-06-23                     71
# 8        0         kirk mosciski           2022-06-23                     71
# 9        0         verda osinski           2022-06-23                     71
# 10       0     lucius mccullough           2022-06-23                     71
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder
df
# Out:
#    at risk                  Name Career Week end date  Days since graduation  \
# 0        0      valentine parker           2022-06-23                     71
# 1        1     gregoria veum iii           2022-06-23                     71
# 2        0     isai turcotte dvm           2022-06-23                     71
# 3        0          alex mueller           2022-06-23                     71
# 4        0            coy kuphal           2022-06-23                     71
# 5        0           janis bayer           2022-06-23                     71
# 6        0     mr. emelia graham           2022-06-23                     71
# 7        0           drake hills           2022-06-23                     71
# 8        0         kirk mosciski           2022-06-23                     71
# 9        0         verda osinski           2022-06-23                     71
# 10       0     lucius mccullough           2022-06-23                     71
# ...

# %%
df.head()
# Out:
#   at risk               Name Career Week end date  Days since graduation  \
# 0       0   valentine parker           2022-06-23                     71
# 1       1  gregoria veum iii           2022-06-23                     71
# 2       0  isai turcotte dvm           2022-06-23                     71
# 3       0       alex mueller           2022-06-23                     71
# 4       0         coy kuphal           2022-06-23                     71
#
#   Cohort Name Outcome Category Outcome Status Track Format Campus  CV  \
# 0     cohort1        searching      searching    wd     ft    rmt   1
# 1     cohort1         excluded   not eligible    wd     ft    rmt   0
# 2     cohort1        searching      searching    wd     ft    rmt   1
# 3     cohort1        searching      searching    wd     ft    rmt   1
# 4     cohort1        searching      searching    wd     ft    rmt   1
#
#    Linkedin  Portfolio  Soft skills score Assessment score  Lab score  \
# ...

# %%
df['Outcome Category'].unique()
# Out:
# array(['searching', 'excluded', 'employed'], dtype=object)

# %%
enc= OrdinalEncoder ()

# %%
df[["Outcome Category"]] = enc.fit_transform(df[["Outcome Category"]])
df
# Out:
#    at risk                  Name Career Week end date  Days since graduation  \
# 0        0      valentine parker           2022-06-23                     71
# 1        1     gregoria veum iii           2022-06-23                     71
# 2        0     isai turcotte dvm           2022-06-23                     71
# 3        0          alex mueller           2022-06-23                     71
# 4        0            coy kuphal           2022-06-23                     71
# 5        0           janis bayer           2022-06-23                     71
# 6        0     mr. emelia graham           2022-06-23                     71
# 7        0           drake hills           2022-06-23                     71
# 8        0         kirk mosciski           2022-06-23                     71
# 9        0         verda osinski           2022-06-23                     71
# 10       0     lucius mccullough           2022-06-23                     71
# ...

# %%
df[["Outcome Status"]] = enc.fit_transform(df[["Outcome Status"]])

# %%
df
# Out:
#    at risk                  Name Career Week end date  Days since graduation  \
# 0        0      valentine parker           2022-06-23                     71
# 1        1     gregoria veum iii           2022-06-23                     71
# 2        0     isai turcotte dvm           2022-06-23                     71
# 3        0          alex mueller           2022-06-23                     71
# 4        0            coy kuphal           2022-06-23                     71
# 5        0           janis bayer           2022-06-23                     71
# 6        0     mr. emelia graham           2022-06-23                     71
# 7        0           drake hills           2022-06-23                     71
# 8        0         kirk mosciski           2022-06-23                     71
# 9        0         verda osinski           2022-06-23                     71
# 10       0     lucius mccullough           2022-06-23                     71
# ...

# %%
df.to_csv('new_datap6.csv')
df
# Out:
#    at risk                  Name Career Week end date  Days since graduation  \
# 0        0      valentine parker           2022-06-23                     71
# 1        1     gregoria veum iii           2022-06-23                     71
# 2        0     isai turcotte dvm           2022-06-23                     71
# 3        0          alex mueller           2022-06-23                     71
# 4        0            coy kuphal           2022-06-23                     71
# 5        0           janis bayer           2022-06-23                     71
# 6        0     mr. emelia graham           2022-06-23                     71
# 7        0           drake hills           2022-06-23                     71
# 8        0         kirk mosciski           2022-06-23                     71
# 9        0         verda osinski           2022-06-23                     71
# 10       0     lucius mccullough           2022-06-23                     71
# ...
