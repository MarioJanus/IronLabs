# %%
import numpy as np
import pandas as pd
df=pd.read_excel(r"C:\Users\Mario\Documents\Labs\Module2\Project_Week7\Sample data set employability__Tableau_temp.xlsx")
df.head(3)
# Out:
#   at risk               Name Career Week end date  Days since graduation  \
# 0     NaN   Valentine Parker           2022-06-23                     71
# 1       🚩  Gregoria Veum III           2022-06-23                     71
# 2     NaN  Isai Turcotte DVM           2022-06-23                     71
#
#   Cohort Name Outcome Category Outcome Status Track Format Campus  CV  \
# 0     Cohort1        Searching      Searching    WD     FT    RMT   1
# 1     Cohort1         Excluded   Not Eligible    WD     FT    RMT   0
# 2     Cohort1        Searching      Searching    WD     FT    RMT   1
#
#    Linkedin  Portfolio  Job ready pct  Soft skills score  Soft skills pct  \
# 0         1        1.0            1.0           3.714286         0.742857
# 1         0        0.0            0.0           1.000000         0.200000
# 2         1        1.0            1.0           3.285714         0.657143
#
#   Assessment score  Lab score  Final project grade  Final project pct
# ...

# %%
df['Days since graduation'] = df['Days since graduation'].astype(int)
df['Portfolio'] = df['Portfolio'].astype(int)
df.head(3)
# Out:
#   at risk               Name Career Week end date  Days since graduation  \
# 0     NaN   Valentine Parker           2022-06-23                     71
# 1       🚩  Gregoria Veum III           2022-06-23                     71
# 2     NaN  Isai Turcotte DVM           2022-06-23                     71
#
#   Cohort Name Outcome Category Outcome Status Track Format Campus  CV  \
# 0     Cohort1        Searching      Searching    WD     FT    RMT   1
# 1     Cohort1         Excluded   Not Eligible    WD     FT    RMT   0
# 2     Cohort1        Searching      Searching    WD     FT    RMT   1
#
#    Linkedin  Portfolio  Job ready pct  Soft skills score  Soft skills pct  \
# 0         1          1            1.0           3.714286         0.742857
# 1         0          0            0.0           1.000000         0.200000
# 2         1          1            1.0           3.285714         0.657143
#
#   Assessment score  Lab score  Final project grade  Final project pct
# ...

# %%
df['Soft skills pct']=df['Soft skills pct'].map(lambda n: '{:,.2%}'.format(n))
df['Job ready pct']=df['Job ready pct'].map(lambda n: '{:,.2%}'.format(n))
df['Final project pct']=df['Final project pct'].map(lambda n: '{:,.2%}'.format(n))

df['Soft skills score']=df['Soft skills score'].map(lambda n: '{:,.3}'.format(n))
df.head(15)
# Out:
#    at risk               Name Career Week end date  Days since graduation  \
# 0      NaN   Valentine Parker           2022-06-23                     71
# 1        🚩  Gregoria Veum III           2022-06-23                     71
# 2      NaN  Isai Turcotte DVM           2022-06-23                     71
# 3      NaN       Alex Mueller           2022-06-23                     71
# 4      NaN         Coy Kuphal           2022-06-23                     71
# 5      NaN        Janis Bayer           2022-06-23                     71
# 6      NaN  Mr. Emelia Graham           2022-06-23                     71
# 7      NaN        Drake Hills           2022-06-23                     71
# 8      NaN      Kirk Mosciski           2022-06-23                     71
# 9      NaN      Verda Osinski           2022-06-23                     71
# 10     NaN  Lucius McCullough           2022-06-23                     71
# 11     NaN    Lilliana Herman           2022-06-23                     71
# ...

# %%
df.head(15)

# %%
df.isnull().sum()

# %%
df['Track']=df['Track'].fillna("WD") 
df['at risk']=df['at risk'].fillna(0)
df.loc[(df['at risk']!=0),"at risk"]=1

# %%
df.head(3)
# Out:
#   at risk               Name Career Week end date  Days since graduation  \
# 0       0   Valentine Parker           2022-06-23                     71
# 1       1  Gregoria Veum III           2022-06-23                     71
# 2       0  Isai Turcotte DVM           2022-06-23                     71
#
#   Cohort Name Outcome Category Outcome Status Track Format Campus  CV  \
# 0     Cohort1        Searching      Searching    WD     FT    RMT   1
# 1     Cohort1         Excluded   Not Eligible    WD     FT    RMT   0
# 2     Cohort1        Searching      Searching    WD     FT    RMT   1
#
#    Linkedin  Portfolio Job ready pct Soft skills score Soft skills pct  \
# 0         1          1       100.00%              3.71          74.29%
# 1         0          0         0.00%               1.0          20.00%
# 2         1          1       100.00%              3.29          65.71%
#
#   Assessment score  Lab score  Final project grade Final project pct
# ...

# %%
df.to_csv('out.csv')
