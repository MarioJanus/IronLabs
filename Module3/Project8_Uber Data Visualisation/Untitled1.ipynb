# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets
from ipywidgets import interact
from ipywidgets import interactive
from IPython.display import display

# %matplotlib inline

data = pd.DataFrame([[3,'VW-b','1 R- R',119.080,'TS',13.56], 
                 [3,'VW-b','1 R- R',119.090,'RS',18.56], 
                 [3,'VW-b','1 R- R',119.100,'TS',12.85],
                 [3,'VW-b','1 R- R',119.110,'TS',9.56],
                 [3,'VW-b','1 R- R',119.120,'RS',8.86],
                 [3,'VW-b','1 R- R',119.130,'TS',13.56],
                 [3,'VW-b','1 R- R',119.140,'TS',19.56],
                 [3,'VW-b','1 R- R',119.150,'TS',14.56],
                 [3,'HRL','1 R- R',159.080,'RS',13.56],
                 [3,'VW-c','1 R- R',19.080,'RS',13.56],
                 [3,'VW-s','1 R- R',254.080,'TS',13.56],
                 [3,'VW-b','1 R- R',25.020,'TS',13.56],
                 [3,'VW-b','1 R- R',25.030,'TS',16.56]], 
                columns=['IGO', 'Baan','Strook','Km','Spoor','IDK1-2'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 data = pd.DataFrame([[3,'VW-b','1 R- R',119.080,'TS',13.56],
#       2                  [3,'VW-b','1 R- R',119.090,'RS',18.56],
#       3                  [3,'VW-b','1 R- R',119.100,'TS',12.85],
#       4                  [3,'VW-b','1 R- R',119.110,'TS',9.56],
#       5                  [3,'VW-b','1 R- R',119.120,'RS',8.86],
#       6                  [3,'VW-b','1 R- R',119.130,'TS',13.56],
#       7                  [3,'VW-b','1 R- R',119.140,'TS',19.56],
#       8                  [3,'VW-b','1 R- R',119.150,'TS',14.56],
#       9                  [3,'HRL','1 R- R',159.080,'RS',13.56],
#      10                  [3,'VW-c','1 R- R',19.080,'RS',13.56],
#      11                  [3,'VW-s','1 R- R',254.080,'TS',13.56],
#      12                  [3,'VW-b','1 R- R',25.020,'TS',13.56],
#      13                  [3,'VW-b','1 R- R',25.030,'TS',16.56]],
#      14                 columns=['IGO', 'Baan','Strook','Km','Spoor','IDK1-2'])
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
import numpy as np
import folium
from folium.plugins import MarkerCluster

stores = [(-23.5578906,-46.6665546, 'store1','electronics'),
             (-23.562711,-46.674363, 'store2','home goods'),
             (-23.5642399,-46.6681833, 'store3','beauty'),
             (-23.584167,-46.678497, 'store4','electronics'),
             (-23.5956238,-46.6865377, 'store5','electronics'),
             (-23.5868682,-46.6773554,'store6','home goods'), 
             (-23.6011096,-46.6739275, 'store7','beauty'),
             (-23.6087354,-46.6973713, 'store8','home goods'),
             (-23.5943515,-46.6846959, 'store9','beauty')]

df = pd.DataFrame(stores, columns=['LAT','LNG','NAME','CATEGORY'])

mymap = folium.Map(location=[df['LAT'].mean(), df['LNG'].mean()], zoom_start=12)

#mCluster = MarkerCluster(name="Stores").add_to(mymap)
mCluster_hg = MarkerCluster(name="home goods").add_to(mymap)
mCluster_ele = MarkerCluster(name="electronics").add_to(mymap)
mCluster_bea = MarkerCluster(name="beauty").add_to(mymap)

for row in df.itertuples():
    #print(row)
    location = row[1], row[2]
    icon=folium.Icon(color='purple', icon='glyphicon-cutlery', prefix='glyphicon')
    html = '''NAME: ''' + row[3] + '''<br>CATEGORY: ''' + row[4]
    iframe = folium.IFrame(html, width=300, height=130)
    popup = folium.Popup(iframe, max_width=300)
    marker = folium.Marker(location=location, popup=popup, icon=icon)
    #folium.Popup(popup).add_to(marker)
    #mCluster_bea.add_child(marker)
    if row[4] == 'electronics':
        mCluster_ele.add_child(marker)
    elif row[4] == 'home goods':
        mCluster_hg.add_child(marker)
    elif row[4] == 'beauty':
        mCluster_bea.add_child(marker)        

folium.LayerControl().add_to(mymap);

mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_59ebeb310484eb5cf58a79e8de7af3d4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_59ebeb310484eb5cf58a79e8de7af3d4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_59ebeb310484eb5cf58a79e8de7af3d4 = L.map(
#                 &quot;map_59ebeb310484eb5cf58a79e8de7af3d4&quot;,
#                 {
#                     center: [-23.583966333333333, -46.67860952222222],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9688cdea7f9bf8cbe331d02cfe04477f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_59ebeb310484eb5cf58a79e8de7af3d4);
#
#
#             var marker_cluster_df6741606cb0868bf311e725e3f26841 = L.markerClusterGroup(
#                 {}
#             );
#             map_59ebeb310484eb5cf58a79e8de7af3d4.addLayer(marker_cluster_df6741606cb0868bf311e725e3f26841);
#
#
#             var marker_ed3b249ad3a4cc34f8fae272f5467413 = L.marker(
#                 [-23.562711, -46.674363],
#                 {}
#             ).addTo(marker_cluster_df6741606cb0868bf311e725e3f26841);
#
#
#             var icon_fe880ebe0660cc87234e134fb74096a3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon-cutlery&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ed3b249ad3a4cc34f8fae272f5467413.setIcon(icon_fe880ebe0660cc87234e134fb74096a3);
#
#
#         var popup_2c58c936acda076d48f1556a0f6b5450 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#             var i_frame_3ae73cff82d0eafbdafc635e43a3971d = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBOQU1FOiBzdG9yZTI8YnI+Q0FURUdPUlk6IGhvbWUgZ29vZHM=&quot; width=&quot;300&quot; style=&quot;border:none !important;&quot; height=&quot;130&quot;&gt;&lt;/iframe&gt;`)[0];
#             popup_2c58c936acda076d48f1556a0f6b5450.setContent(i_frame_3ae73cff82d0eafbdafc635e43a3971d);
#
#
#         marker_ed3b249ad3a4cc34f8fae272f5467413.bindPopup(popup_2c58c936acda076d48f1556a0f6b5450)
#         ;
#
#
#
#
#             var marker_8f3e5f0b9a5dca183235e6ed5d0d9a33 = L.marker(
#                 [-23.5868682, -46.6773554],
#                 {}
#             ).addTo(marker_cluster_df6741606cb0868bf311e725e3f26841);
#
#
#             var icon_18e00c9612ffdc6fdc5438949f8d8ab5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon-cutlery&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8f3e5f0b9a5dca183235e6ed5d0d9a33.setIcon(icon_18e00c9612ffdc6fdc5438949f8d8ab5);
#
#
#         var popup_5dad3bac46f68c760c73ab02e1b15c2c = L.popup({&quot;maxWidth&quot;: 300});
#
#
#             var i_frame_cff195575c7adc1fda75b32227e0de7b = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBOQU1FOiBzdG9yZTY8YnI+Q0FURUdPUlk6IGhvbWUgZ29vZHM=&quot; width=&quot;300&quot; style=&quot;border:none !important;&quot; height=&quot;130&quot;&gt;&lt;/iframe&gt;`)[0];
#             popup_5dad3bac46f68c760c73ab02e1b15c2c.setContent(i_frame_cff195575c7adc1fda75b32227e0de7b);
#
#
#         marker_8f3e5f0b9a5dca183235e6ed5d0d9a33.bindPopup(popup_5dad3bac46f68c760c73ab02e1b15c2c)
#         ;
#
#
#
#
#             var marker_0d2a869e2f71e8d5afa61d49dfeb94d3 = L.marker(
#                 [-23.6087354, -46.6973713],
#                 {}
#             ).addTo(marker_cluster_df6741606cb0868bf311e725e3f26841);
#
#
#             var icon_6534908e12bcaf20a35f33ac148c7274 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon-cutlery&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0d2a869e2f71e8d5afa61d49dfeb94d3.setIcon(icon_6534908e12bcaf20a35f33ac148c7274);
#
#
#         var popup_7c48de0fc04897854d5b105d44f5c09a = L.popup({&quot;maxWidth&quot;: 300});
#
#
#             var i_frame_3d795ca09ca7538e9662cff054000ca4 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBOQU1
