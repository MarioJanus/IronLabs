# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = 'https://github.com/trending/developers'
html = requests.get(url).content

sp=BeautifulSoup(html, "lxml")
tags=['text']
sp
#text=[element.text for element in soup.find_all(tags)]
#print('\n'.join(text))
# Out:
# <!DOCTYPE html>
# <html data-a11y-animated-images="system" data-color-mode="auto" data-dark-theme="dark" data-light-theme="light" lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="" href="https://github.githubassets.com" rel="preconnect"/>
# <link href="https://avatars.githubusercontent.com" rel="preconnect"/>
# ...

# %%
response=requests.get(url).content
sp=BeautifulSoup(response, 'lxml')
sp
# Out:
# <!DOCTYPE html>
# <html data-a11y-animated-images="system" data-color-mode="auto" data-dark-theme="dark" data-light-theme="light" lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="" href="https://github.githubassets.com" rel="preconnect"/>
# <link href="https://avatars.githubusercontent.com" rel="preconnect"/>
# ...

# %%
#soup.get_text()
response=requests.get(url).content
sp=BeautifulSoup(response, 'lxml')
tags='p'
text=[element.text for element in sp.find_all(tags)]

# %%
printtext
# Out:
# ['\n      These are the developers building the hot tools today.\n    ',
#  '\n\n              jaraco\n ',
#  '\n\n              stefanprodan\n ',
#  '\n\n              sirbrillig\n ',
#  '\n\n              wcandillon\n ',
#  '\n\n              chihsuan\n ',
#  '\n\n              evanw\n ',
#  '\n\n              guolinke\n ',
#  '\n\n              a8m\n ',
#  '\n\n              benbjohnson\n ',
#  '\n\n              jhump\n ',
#  '\n\n Atlanta, GA',
#  '\n\n              lmiller1990\n ',
#  '\n\n              mfrw\n ',
#  '\n\n /dev/random',
#  '\n\n              rom1504\n ',
#  '\n\n              apparentlymart\n ',
#  '\n\n Portland, OR',
#  '\n\n              DonJayamanne\n ',
#  '\n\n              seokho-son\n ',
#  '\n\n ETRI (한국전자통신연구원)',
#  '\n\n              nvbn\n ',
#  '\n\n              maxbrunsfeld\n ',
#  '\n\n              hypnoglow\n ',
#  '\n\n Joined on Jun 27, 2013',
#  '\n\n              benfred\n ',
#  '\n\n              jkroepke\n ',
# ...

# %%
url='https://en.wikipedia.org/wiki/Walt_Disney'
response=requests.get(url).content
response
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Walt Disney - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"f285de0c-99ff-4dab-8ce5-7a4eec3e4653","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Walt_Disney","wgTitle":"Walt Disney","wgCurRevisionId":1104434623,"wgRevisionId":1104434623,"wgArticleId":32917,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Pages containing links to subscription-only content","Articles with short description","Short description matches Wikidata","Featured articles","Wikiped
# ...

# %%
url = 'http://uscode.house.gov/download/download.shtml'
sp=BeautifulSoup(response, 'lxml')
imgs=sp.find_all('img')
imgs

liste=sp.find_all('div',{{'class'}:'usctitllechanged'})
# Out:
#   Input In [19]
#     liste=sp.find_all('div',{'class'}:'usctitllechanged')
#                                      ^
# SyntaxError: invalid syntax

# %%
cols=[colnames.text]

# %%
title = [i.text for i in soup.select("div.row h3")]
city = [j.text.strip().split(",")[0] for j in soup.select("div.row p:has(i.fa-map-marker-alt)")]
country = [j.text.strip().split(",")[1] for j in soup.select("div.row p:has(i.fa-map-marker-alt)")]
when1 =[j.text.strip().split()[1] for j in soup.select("div.row p:has(i.fa-calendar-check)")]
when2 = [j.text.strip().split()[1] for j in soup.select("div.row p:has(i.fa-calendar-times)")]
when1[0]
