# %%
import json
import requests

response = requests.get('https://jsonplaceholder.typicode.com/todos')
results = response.json()
results

import pandas as pd
data = pd.DataFrame(results)
data.head(10)

response = requests.get('https://api.github.com/events')
results = response.json()
data = pd.DataFrame(response.())
data.head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 14>()
#      12 response = requests.get('https://api.github.com/events')
#      13 results = response.json()
# ---> 14 data = pd.DataFrame(results())
#      15 data.head(10)
#
# TypeError: 'list' object is not callable

# %%
response = requests.get('https://api.github.com/events')

data = pd.DataFrame(response.json())
data.head(10)
# Out:
#             id                    type  \
# 0  23187364403             MemberEvent
# 1  23187364389               PushEvent
# 2  23187364434               PushEvent
# 3  23187364392  PullRequestReviewEvent
# 4  23187364421               PushEvent
# 5  23187364401               PushEvent
# 6  23187364411              WatchEvent
# 7  23187364407              WatchEvent
# 8  23187364350       IssueCommentEvent
# 9  23187364297               PushEvent
#
#                                                actor  \
# 0  {'id': 47969058, 'login': 'vitaliivepsha', 'di...
# 1  {'id': 22415594, 'login': 'ruanwenjun', 'displ...
# 2  {'id': 41898282, 'login': 'github-actions[bot]...
# 3  {'id': 1347065, 'login': 'romseygeek', 'displa...
# 4  {'id': 79998603, 'login': 'sanchay-1109', 'dis...
# 5  {'id': 28799675, 'login': 'AndroBuddy', 'displ...
# 6  {'id': 93521857, 'login': 'oleksandra-lavryk',...
# 7  {'id': 42862501, 'login': 'DD384789980', 'disp...
# 8  {'id': 75433959, 'login': 'openshift-ci[bot]',...
# 9  {'id': 34628766, 'login': 'roccqqck', 'display...
#
#                                                 repo  \
# 0  {'id': 516648394, 'name': 'vitaliivepsha/edelm...
# 1  {'id': 173335706, 'name': 'apache/dolphinsched...
# 2  {'id': 279506430, 'name': 'acgfunny/-4', 'url'...
# 3  {'id': 507775, 'name': 'elastic/elasticsearch'...
# 4  {'id': 519542770, 'name': 'sanchay-1109/Geek_o...
# 5  {'id': 520002051, 'name': 'MU-Enigma/store', '...
# 6  {'id': 481917414, 'name': 'oleksandra-lavryk/m...
# 7  {'id': 291371102, 'name': 'mindskip/xzs-mysql'...
# 8  {'id': 146928856, 'name': 'openshift/cluster-n...
# 9  {'id': 519930731, 'name': 'roccqqck/go-lession...
#
#                                              payload  public  \
# 0  {'member': {'login': 'titarsv', 'id': 15159468...    True
# 1  {'push_id': 10600824327, 'size': 1, 'distinct_...    True
# 2  {'push_id': 10600824590, 'size': 1, 'distinct_...    True
# 3  {'action': 'created', 'review': {'id': 1057014...    True
# 4  {'push_id': 10600824583, 'size': 1, 'distinct_...    True
# 5  {'push_id': 10600824594, 'size': 1, 'distinct_...    True
# 6                              {'action': 'started'}    True
# 7                              {'action': 'started'}    True
# 8  {'action': 'created', 'issue': {'url': 'https:...    True
# 9  {'push_id': 10600824537, 'size': 1, 'distinct_...    True
#
#              created_at                                                org
# 0  2022-08-01T09:32:35Z                                                NaN
# 1  2022-08-01T09:32:35Z  {'id': 47359, 'login': 'apache', 'gravatar_id'...
# 2  2022-08-01T09:32:35Z                                                NaN
# 3  2022-08-01T09:32:35Z  {'id': 6764390, 'login': 'elastic', 'gravatar_...
# 4  2022-08-01T09:32:35Z                                                NaN
# 5  2022-08-01T09:32:35Z  {'id': 26093719, 'login': 'MU-Enigma', 'gravat...
# 6  2022-08-01T09:32:35Z                                                NaN
# 7  2022-08-01T09:32:35Z                                                NaN
# 8  2022-08-01T09:32:35Z  {'id': 792337, 'login': 'openshift', 'gravatar...
# 9  2022-08-01T09:32:35Z                                                NaN

# %%
def flatten(data, col_list):
    for column in col_list:
        flattened = pd.DataFrame(dict(data[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        data = pd.concat([data, flattened], axis=1)
        data = data.drop(column, axis=1)
    return data
nested_columns = ['actor', 'org', 'payload', 'repo']

flat = flatten(data, nested_columns)


flat.head(10)
# Out:
#             id                    type  public            created_at  \
# 0  23187364403             MemberEvent    True  2022-08-01T09:32:35Z
# 1  23187364389               PushEvent    True  2022-08-01T09:32:35Z
# 2  23187364434               PushEvent    True  2022-08-01T09:32:35Z
# 3  23187364392  PullRequestReviewEvent    True  2022-08-01T09:32:35Z
# 4  23187364421               PushEvent    True  2022-08-01T09:32:35Z
# 5  23187364401               PushEvent    True  2022-08-01T09:32:35Z
# 6  23187364411              WatchEvent    True  2022-08-01T09:32:35Z
# 7  23187364407              WatchEvent    True  2022-08-01T09:32:35Z
# 8  23187364350       IssueCommentEvent    True  2022-08-01T09:32:35Z
# 9  23187364297               PushEvent    True  2022-08-01T09:32:35Z
#
#    actor_id          actor_login actor_display_login actor_gravatar_id  \
# 0  47969058        vitaliivepsha       vitaliivepsha
# 1  22415594           ruanwenjun          ruanwenjun
# 2  41898282  github-actions[bot]      github-actions
# 3   1347065           romseygeek          romseygeek
# 4  79998603         sanchay-1109        sanchay-1109
# 5  28799675           AndroBuddy          AndroBuddy
# 6  93521857    oleksandra-lavryk   oleksandra-lavryk
# 7  42862501          DD384789980         DD384789980
# 8  75433959    openshift-ci[bot]        openshift-ci
# 9  34628766             roccqqck            roccqqck
#
#                                           actor_url  \
# 0        https://api.github.com/users/vitaliivepsha
# 1           https://api.github.com/users/ruanwenjun
# 2  https://api.github.com/users/github-actions[bot]
# 3           https://api.github.com/users/romseygeek
# 4         https://api.github.com/users/sanchay-1109
# 5           https://api.github.com/users/AndroBuddy
# 6    https://api.github.com/users/oleksandra-lavryk
# 7          https://api.github.com/users/DD384789980
# 8    https://api.github.com/users/openshift-ci[bot]
# 9             https://api.github.com/users/roccqqck
#
#                                     actor_avatar_url  ...  \
# 0  https://avatars.githubusercontent.com/u/47969058?  ...
# 1  https://avatars.githubusercontent.com/u/22415594?  ...
# 2  https://avatars.githubusercontent.com/u/41898282?  ...
# 3   https://avatars.githubusercontent.com/u/1347065?  ...
# 4  https://avatars.githubusercontent.com/u/79998603?  ...
# 5  https://avatars.githubusercontent.com/u/28799675?  ...
# 6  https://avatars.githubusercontent.com/u/93521857?  ...
# 7  https://avatars.githubusercontent.com/u/42862501?  ...
# 8  https://avatars.githubusercontent.com/u/75433959?  ...
# 9  https://avatars.githubusercontent.com/u/34628766?  ...
#
#                                      payload_comment payload_number  \
# 0                                                NaN            NaN
# 1                                                NaN            NaN
# 2                                                NaN            NaN
# 3                                                NaN            NaN
# 4                                                NaN            NaN
# 5                                                NaN            NaN
# 6                                                NaN            NaN
# 7                                                NaN            NaN
# 8  {'url': 'https://api.github.com/repos/openshif...            NaN
# 9                                                NaN            NaN
#
#   payload_ref_type payload_pusher_type payload_pages payload_master_branch  \
# 0              NaN                 NaN           NaN                   NaN
# 1              NaN                 NaN           NaN                   NaN
# 2              NaN                 NaN           NaN                   NaN
# 3              NaN                 NaN           NaN                   NaN
# 4              NaN                 NaN           NaN                   NaN
# 5              NaN                 NaN           NaN                   NaN
# 6              NaN                 NaN           NaN                   NaN
# 7              NaN                 NaN           NaN                   NaN
# 8              NaN                 NaN           NaN                   NaN
# 9              NaN                 NaN           NaN                   NaN
#
#   payload_description    repo_id                                repo_name  \
# 0                 NaN  516648394           vitaliivepsha/edelmetallhandel
# 1                 NaN  173335706                  apache/dolphinscheduler
# 2                 NaN  279506430                              acgfunny/-4
# 3                 NaN     507775                    elastic/elasticsearch
# 4                 NaN  519542770       sanchay-1109/Geek_o_Engineers_Blog
# 5                 NaN  520002051                          MU-Enigma/store
# 6                 NaN  481917414           oleksandra-lavryk/meal-sharing
# 7                 NaN  291371102                       mindskip/xzs-mysql
# 8                 NaN  146928856       openshift/cluster-network-operator
# 9                 NaN  519930731  roccqqck/go-lessions-from-google-senior
#
#                                             repo_url
# 0  https://api.github.com/repos/vitaliivepsha/ede...
# 1  https://api.github.com/repos/apache/dolphinsch...
# 2           https://api.github.com/repos/acgfunny/-4
# 3  https://api.github.com/repos/elastic/elasticse...
# 4  https://api.github.com/repos/sanchay-1109/Geek...
# 5       https://api.github.com/repos/MU-Enigma/store
# 6  https://api.github.com/repos/oleksandra-lavryk...
# 7    https://api.github.com/repos/mindskip/xzs-mysql
# 8  https://api.github.com/repos/openshift/cluster...
# 9  https://api.github.com/repos/roccqqck/go-lessi...
#
# [10 rows x 37 columns]

# %%
results = response.json()
flattened_data = pd.json_normalize(results)

flattened_data
# Out:
#              id                    type  public            created_at  \
# 0   23187364403             MemberEvent    True  2022-08-01T09:32:35Z
# 1   23187364389               PushEvent    True  2022-08-01T09:32:35Z
# 2   23187364434               PushEvent    True  2022-08-01T09:32:35Z
# 3   23187364392  PullRequestReviewEvent    True  2022-08-01T09:32:35Z
# 4   23187364421               PushEvent    True  2022-08-01T09:32:35Z
# 5   23187364401               PushEvent    True  2022-08-01T09:32:35Z
# 6   23187364411              WatchEvent    True  2022-08-01T09:32:35Z
# 7   23187364407              WatchEvent    True  2022-08-01T09:32:35Z
# 8   23187364350       IssueCommentEvent    True  2022-08-01T09:32:35Z
# 9   23187364297               PushEvent    True  2022-08-01T09:32:35Z
# 10  23187364272               PushEvent    True  2022-08-01T09:32:35Z
# 11  23187364249               PushEvent    True  2022-08-01T09:32:35Z
# 12  23187364319        PullRequestEvent    True  2022-08-01T09:32:35Z
# 13  23187364307              WatchEvent    True  2022-08-01T09:32:35Z
# 14  23187364288        PullRequestEvent    True  2022-08-01T09:32:35Z
# 15  23187364260             DeleteEvent    True  2022-08-01T09:32:35Z
# 16  23187364259             GollumEvent    True  2022-08-01T09:32:35Z
# 17  23187364283             DeleteEvent    True  2022-08-01T09:32:35Z
# 18  23187364212        PullRequestEvent    True  2022-08-01T09:32:35Z
# 19  23187364211               PushEvent    True  2022-08-01T09:32:35Z
# 20  23187364155        PullRequestEvent    True  2022-08-01T09:32:34Z
# 21  23187364144               PushEvent    True  2022-08-01T09:32:34Z
# 22  23187364166               PushEvent    True  2022-08-01T09:32:34Z
# 23  23187364177             DeleteEvent    True  2022-08-01T09:32:34Z
# 24  23187364169             CreateEvent    True  2022-08-01T09:32:34Z
# 25  23187364170             CreateEvent    True  2022-08-01T09:32:34Z
# 26  23187364109               PushEvent    True  2022-08-01T09:32:34Z
# 27  23187364078        PullRequestEvent    True  2022-08-01T09:32:34Z
# 28  23187364092               PushEvent    True  2022-08-01T09:32:34Z
# 29  23187364107        PullRequestEvent    True  2022-08-01T09:32:34Z
#
#      actor.id          actor.login actor.display_login actor.gravatar_id  \
# 0    47969058        vitaliivepsha       vitaliivepsha
# 1    22415594           ruanwenjun          ruanwenjun
# 2    41898282  github-actions[bot]      github-actions
# 3     1347065           romseygeek          romseygeek
# 4    79998603         sanchay-1109        sanchay-1109
# 5    28799675           AndroBuddy          AndroBuddy
# 6    93521857    oleksandra-lavryk   oleksandra-lavryk
# 7    42862501          DD384789980         DD384789980
# 8    75433959    openshift-ci[bot]        openshift-ci
# 9    34628766             roccqqck            roccqqck
# 10   70098543          tndud042713         tndud042713
# 11   41898282  github-actions[bot]      github-actions
# 12   61758357       gabrielmorandi      gabrielmorandi
# 13   43238557              RebornQ             RebornQ
# 14   10071857            bangank36           bangank36
# 15   49699333      dependabot[bot]          dependabot
# 16   79194096          Saba-sports         Saba-sports
# 17   30697622     FirelightFlagboy    FirelightFlagboy
# 18   51625871           islakhun24          islakhun24
# 19   98509058        Legend-Mukund       Legend-Mukund
# 20   64278297              gdpbalt             gdpbalt
# 21   99871949       DimitriyPython      DimitriyPython
# 22   25117244          xihuishawpy         xihuishawpy
# 23  110376837         FriscicBojan        FriscicBojan
# 24   87622104               Alilux              Alilux
# 25   49699333      dependabot[bot]          dependabot
# 26   40665208           Vladikasik          Vladikasik
# 27     855789            TheEmidee           TheEmidee
# 28   35500879       Yashaswini1998      Yashaswini1998
# 29   30697622     FirelightFlagboy    FirelightFlagboy
#
#                                            actor.url  \
# 0         https://api.github.com/users/vitaliivepsha
# 1            https://api.github.com/users/ruanwenjun
# 2   https://api.github.com/users/github-actions[bot]
# 3            https://api.github.com/users/romseygeek
# 4          https://api.github.com/users/sanchay-1109
# 5            https://api.github.com/users/AndroBuddy
# 6     https://api.github.com/users/oleksandra-lavryk
# 7           https://api.github.com/users/DD384789980
# 8     https://api.github.com/users/openshift-ci[bot]
# 9              https://api.github.com/users/roccqqck
# 10          https://api.github.com/users/tndud042713
# 11  https://api.github.com/users/github-actions[bot]
# 12       https://api.github.com/users/gabrielmorandi
# 13              https://api.github.com/users/RebornQ
# 14            https://api.github.com/users/bangank36
# 15      https://api.github.com/users/dependabot[bot]
# 16          https://api.github.com/users/Saba-sports
# 17     https://api.github.com/users/FirelightFlagboy
# 18           https://api.github.com/users/islakhun24
# 19        https://api.github.com/users/Legend-Mukund
# 20              https://api.github.com/users/gdpbalt
# 21       https://api.github.com/users/DimitriyPython
# 22          https://api.github.com/users/xihuishawpy
# 23         https://api.github.com/users/FriscicBojan
# 24               https://api.github.com/users/Alilux
# 25      https://api.github.com/users/dependabot[bot]
# 26           https://api.github.com/users/Vladikasik
# 27            https://api.github.com/users/TheEmidee
# 28       https://api.github.com/users/Yashaswini1998
# 29     https://api.github.com/users/FirelightFlagboy
#
#                                      actor.avatar_url  ...  \
# 0   https://avatars.githubusercontent.com/u/47969058?  ...
# 1   https://avatars.githubusercontent.com/u/22415594?  ...
# 2   https://avatars.githubusercontent.com/u/41898282?  ...
# 3    https://avatars.githubusercontent.com/u/1347065?  ...
# 4   https://avatars.githubusercontent.com/u/79998603?  ...
# 5   https://avatars.githubusercontent.com/u/28799675?  ...
# 6   https://avatars.githubusercontent.com/u/93521857?  ...
# 7   https://avatars.githubusercontent.com/u/42862501?  ...
# 8   https://avatars.githubusercontent.com/u/75433959?  ...
# 9   https://avatars.githubusercontent.com/u/34628766?  ...
# 10  https://avatars.githubusercontent.com/u/70098543?  ...
# 11  https://avatars.githubusercontent.com/u/41898282?  ...
# 12  https://avatars.githubusercontent.com/u/61758357?  ...
# 13  https://avatars.githubusercontent.com/u/43238557?  ...
# 14  https://avatars.githubusercontent.com/u/10071857?  ...
# 15  https://avatars.githubusercontent.com/u/49699333?  ...
# 16  https://avatars.githubusercontent.com/u/79194096?  ...
# 17  https://avatars.githubusercontent.com/u/30697622?  ...
# 18  https://avatars.githubusercontent.com/u/51625871?  ...
# 19  https://avatars.githubusercontent.com/u/98509058?  ...
# 20  https://avatars.githubusercontent.com/u/64278297?  ...
# 21  https://avatars.githubusercontent.com/u/99871949?  ...
# 22  https://avatars.githubusercontent.com/u/25117244?  ...
# 23  https://avatars.githubusercontent.com/u/110376...  ...
# 24  https://avatars.githubusercontent.com/u/87622104?  ...
# 25  https://avatars.githubusercontent.com/u/49699333?  ...
# 26  https://avatars.githubusercontent.com/u/40665208?  ...
# 27    https://avatars.githubusercontent.com/u/855789?  ...
# 28  https://avatars.githubusercontent.com/u/35500879?  ...
# 29  https://avatars.githubusercontent.com/u/30697622?  ...
#
#              payload.pull_request.merged_by.repos_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14       https://api.github.com/users/bangank36/repos
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29  https://api.github.com/users/FirelightFlagboy/...
#
#             payload.pull_request.merged_by.events_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  https://api.github.com/users/bangank36/events{...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29  https://api.github.com/users/FirelightFlagboy/...
#
#    payload.pull_request.merged_by.received_events_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  https://api.github.com/users/bangank36/receive...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29  https://api.github.com/users/FirelightFlagboy/...
#
#    payload.pull_request.merged_by.type  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# 5                                  NaN
# 6                                  NaN
# 7                                  NaN
# 8                                  NaN
# 9                                  NaN
# 10                                 NaN
# 11                                 NaN
# 12                                 NaN
# 13                                 NaN
# 14                                User
# 15                                 NaN
# 16                                 NaN
# 17                                 NaN
# 18                                 NaN
# 19                                 NaN
# 20                                 NaN
# 21                                 NaN
# 22                                 NaN
# 23                                 NaN
# 24                                 NaN
# 25                                 NaN
# 26                                 NaN
# 27                                 NaN
# 28                                 NaN
# 29                                User
#
#     payload.pull_request.merged_by.site_admin payload.ref_type  \
# 0                                         NaN              NaN
# 1                                         NaN              NaN
# 2                                         NaN              NaN
# 3                                         NaN              NaN
# 4                                         NaN              NaN
# 5                                         NaN              NaN
# 6                                         NaN              NaN
# 7                                         NaN              NaN
# 8                                         NaN              NaN
# 9                                         NaN              NaN
# 10                                        NaN              NaN
# 11                                        NaN              NaN
# 12                                        NaN              NaN
# 13                                        NaN              NaN
# 14                                      False              NaN
# 15                                        NaN           branch
# 16                                        NaN              NaN
# 17                                        NaN           branch
# 18                                        NaN              NaN
# 19                                        NaN              NaN
# 20                                        NaN              NaN
# 21                                        NaN              NaN
# 22                                        NaN              NaN
# 23                                        NaN           branch
# 24                                        NaN           branch
# 25                                        NaN           branch
# 26                                        NaN              NaN
# 27                                        NaN              NaN
# 28                                        NaN              NaN
# 29                                      False              NaN
#
#    payload.pusher_type                                      payload.pages  \
# 0                  NaN                                                NaN
# 1                  NaN                                                NaN
# 2                  NaN                                                NaN
# 3                  NaN                                                NaN
# 4                  NaN                                                NaN
# 5                  NaN                                                NaN
# 6                  NaN                                                NaN
# 7                  NaN                                                NaN
# 8                  NaN                                                NaN
# 9                  NaN                                                NaN
# 10                 NaN                                                NaN
# 11                 NaN                                                NaN
# 12                 NaN                                                NaN
# 13                 NaN                                                NaN
# 14                 NaN                                                NaN
# 15                user                                                NaN
# 16                 NaN  [{'page_name': 'Sport-Table', 'title': 'Sport ...
# 17                user                                                NaN
# 18                 NaN                                                NaN
# 19                 NaN                                                NaN
# 20                 NaN                                                NaN
# 21                 NaN                                                NaN
# 22                 NaN                                                NaN
# 23                user                                                NaN
# 24                user                                                NaN
# 25                user                                                NaN
# 26                 NaN                                                NaN
# 27                 NaN                                                NaN
# 28                 NaN                                                NaN
# 29                 NaN                                                NaN
#
#    payload.master_branch                      payload.description
# 0                    NaN                                      NaN
# 1                    NaN                                      NaN
# 2                    NaN                                      NaN
# 3                    NaN                                      NaN
# 4                    NaN                                      NaN
# 5                    NaN                                      NaN
# 6                    NaN                                      NaN
# 7                    NaN                                      NaN
# 8                    NaN                                      NaN
# 9                    NaN                                      NaN
# 10                   NaN                                      NaN
# 11                   NaN                                      NaN
# 12                   NaN                                      NaN
# 13                   NaN                                      NaN
# 14                   NaN                                      NaN
# 15                   NaN                                      NaN
# 16                   NaN                                      NaN
# 17                   NaN                                      NaN
# 18                   NaN                                      NaN
# 19                   NaN                                      NaN
# 20                   NaN                                      NaN
# 21                   NaN                                      NaN
# 22                   NaN                                      NaN
# 23                   NaN                                      NaN
# 24                canary                      The React Framework
# 25                  main  Azure Pipelines extension for Terraform
# 26                   NaN                                      NaN
# 27                   NaN                                      NaN
# 28                   NaN                                      NaN
# 29                   NaN                                      NaN
#
# [30 rows x 525 columns]
