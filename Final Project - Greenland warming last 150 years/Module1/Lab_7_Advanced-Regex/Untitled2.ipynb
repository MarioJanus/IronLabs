# %%
import requests
import random
import PyGithub
receive=requests.get('https://xkcd.com/')
print(receive.headers) #get header
latest_comic=requests.get('https://xkcd.com/info.0.json')
latest_comic_result=latest_comic.json()
random_number=random.choice(range(1, latest_comic_result['num']+1))
random_comic=requests.get(f'https://xkcd.com/{random_number}/info.0.json')
random_comic_results=random_comic.json


print(receive.content) #get HTML code


with open(r'C:\Users\Mario\Documents\Privat\Week2\image1.png','wb') as f:
    f.write(receive1.content)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [91], in <cell line: 3>()
#       1 import requests
#       2 import random
# ----> 3 import PyGithub
#       4 receive=requests.get('https://xkcd.com/')
#       5 print(receive.headers) #get header
#
# ModuleNotFoundError: No module named 'PyGithub'

# %%
import requests

receive=requests.get('https://httpbin.org/get')
print(receive.headers) #getting Header

parameters={'things':2,'total':25, 'Username': 'u', 'Password': 'p'}  #set parameters                  
receive=requests.get('https://httpbin.org/get', params=parameters)
print(receive.content)
receive.json()['args'] #call args from pulled(get) request
with open(r'C:\Users\Mario\Documents\Privat\Week2\auth.txt','wb') as f:
    f.write(receive.content)
# Out:
# {'Date': 'Mon, 01 Aug 2022 13:18:27 GMT', 'Content-Type': 'application/json', 'Content-Length': '313', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}
# b'{\n  "args": {\n    "Password": "p", \n    "Username": "u", \n    "things": "2", \n    "total": "25"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate, br", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.27.1", \n    "X-Amzn-Trace-Id": "Root=1-62e7d2a3-1c6442d415194d002242cac9"\n  }, \n  "origin": "195.134.167.217", \n  "url": "https://httpbin.org/get?things=2&total=25&Username=u&Password=p"\n}\n'

# %%
receive=requests.get('https://github.com/ironhack-datalabs/scavenger')
print(receive.content)
# Out:
# b'\n\n\n\n\n\n\n<!DOCTYPE html>\n<html lang="en" data-color-mode="auto" data-light-theme="light" data-dark-theme="dark" data-a11y-animated-images="system">\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n  <link rel="preconnect" href="https://github.githubassets.com" crossorigin>\n  <link rel="preconnect" href="https://avatars.githubusercontent.com">\n\n\n\n  <link crossorigin="anonymous" media="all" integrity="sha512-UXiu4O52iBFkqt6Kx5t+pqHYP2/LWWIw9+l5ia74TWw+xPzpH44BFfAQp7yzCe0XFGZa72Xiqyml6tox1KkUjw==" rel="stylesheet" href="https://github.githubassets.com/assets/light-5178aee0ee76.css" /><link crossorigin="anonymous" media="all" integrity="sha512-IX1PnI5wWBz8Kgb1JI0f2QFa/WuRQQHJHe0vkKinQzsxRlNb4b8N
# ...

# %%
pip install tweepy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached tweepy-4.10.0-py3-none-any.whl (94 kB)
# ...
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# ...
#   Using cached oauthlib-3.2.0-py3-none-any.whl (151 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
